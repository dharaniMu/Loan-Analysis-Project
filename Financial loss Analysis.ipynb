# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt,seaborn as sns
# %matplotlib inline

# %%
loandata=pd.read_csv("loan.csv")

# %%
loandata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
loandata.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %% [markdown]
# # Null Values Count

# %%
nullvalues=loandata.isnull().sum()/loandata.shape[0]*100

# %%
nullvalues.tail(52)
# Out:
# open_acc_6m                       100.000000
# open_il_6m                        100.000000
# open_il_12m                       100.000000
# open_il_24m                       100.000000
# mths_since_rcnt_il                100.000000
# total_bal_il                      100.000000
# il_util                           100.000000
# open_rv_12m                       100.000000
# open_rv_24m                       100.000000
# max_bal_bc                        100.000000
# all_util                          100.000000
# total_rev_hi_lim                  100.000000
# inq_fi                            100.000000
# total_cu_tl                       100.000000
# inq_last_12m                      100.000000
# acc_open_past_24mths              100.000000
# avg_cur_bal                       100.000000
# bc_open_to_buy                    100.000000
# bc_util                           100.000000
# chargeoff_within_12_mths            0.140998
# delinq_amnt                         0.000000
# ...

# %%
loandata.drop(["desc","mths_since_last_delinq","mths_since_last_record","next_pymnt_d","mths_since_last_major_derog","annual_inc_joint","dti_joint","verification_status_joint","tot_coll_amt","tot_cur_bal","open_acc_6m","open_acc_6m","open_il_6m","open_il_12m","open_il_24m", "mths_since_rcnt_il","total_bal_il","il_util","open_rv_12m","open_rv_24m","max_bal_bc","all_util",
"total_rev_hi_lim","inq_fi","total_cu_tl","inq_last_12m","acc_open_past_24mths","avg_cur_bal","bc_open_to_buy",
"bc_util",'mo_sin_old_il_acct',
 'mo_sin_old_rev_tl_op',
 'mo_sin_rcnt_rev_tl_op',
 'mo_sin_rcnt_tl',
 'mort_acc',
 'mths_since_recent_bc',
 'mths_since_recent_bc_dlq',
 'mths_since_recent_inq',
 'mths_since_recent_revol_delinq',
 'num_accts_ever_120_pd',
 'num_actv_bc_tl',
 'num_actv_rev_tl',
 'num_bc_sats',
 'num_bc_tl',
 'num_il_tl',
 'num_op_rev_tl',
 'num_rev_accts',
 'num_rev_tl_bal_gt_0',
 'num_sats',
 'num_tl_120dpd_2m',
 'num_tl_30dpd',
 'num_tl_90g_dpd_24m',
 'num_tl_op_past_12m',
 'pct_tl_nvr_dlq',
 'percent_bc_gt_75','tot_hi_cred_lim',
 'total_bal_ex_mort',
 'total_bc_limit',
 'total_il_high_credit_limit'],axis=1,inplace=True)

# %%
loandata.shape
# Out:
# (39717, 53)

# %%
loandata.annual_inc.min()
# Out:
# 4000.0

# %%
loandata.annual_inc.max()
# Out:
# 6000000.0

# %%
def func(loandata):
    loandata.loc[(loandata["annual_inc"] >= 4000) & (loandata["annual_inc"] <=50000), "annual_inc_range"] = "very low"
    loandata.loc[(loandata["annual_inc"] > 50000) & (loandata["annual_inc"] <=100000), "annual_inc_range"] = "low"
    loandata.loc[(loandata["annual_inc"] > 100000) & (loandata["annual_inc"] <= 1000000), "annual_inc_range"] = "medium"
    loandata.loc[(loandata["annual_inc"] > 1000000) & (loandata["annual_inc"] <=6000000), "annual_inc_range"] = "high"
    
    return loandata

result = func(loandata)

# %%
loandata["Verificationstatus_flag"]=np.where(loandata.loan_status=="Not Verified",1,0)

# %%
fully_paid_data = loandata[loandata["loan_status"] == "Fully Paid"]

# %%
loan_purpose_data=fully_paid_data.groupby("purpose")["loan_status"].count().reset_index()

# %%
loan_purpose_data["Verificationstatus_flag"]=loandata["Verificationstatus_flag"].copy()

# %%
loan_purpose_data
# Out:
#                purpose  loan_status  Verificationstatus_flag
# 0                  car         1339                        0
# 1          credit_card         4485                        0
# 2   debt_consolidation        15288                        0
# 3          educational          269                        0
# 4     home_improvement         2528                        0
# 5                house          308                        0
# 6       major_purchase         1928                        0
# 7              medical          575                        0
# 8               moving          484                        0
# 9                other         3232                        0
# 10    renewable_energy           83                        0
# 11      small_business         1279                        0
# 12            vacation          322                        0
# 13             wedding          830                        0

# %% [markdown]
# Most of the fully_paid people are Verified for the loan

# %%
verified_data=loandata[loandata["verification_status"]=="Not Verified"]
home_verif_data=verified_data.groupby("home_ownership")["verification_status"].count().reset_index()

# %%
sns.barplot(data=home_verif_data,x="home_ownership",y="verification_status",palette=sns.color_palette())
plt.show()

# %% [markdown]
# Ownhouse people are not getting the loan .This could affect the company growth because the ownhouse is the surity for the recovery of loan if they are not paid
